# %% [markdown]
# # Data Exploration
#
# This is where we explore our data sets to get an idea of what the data they contain is and how it is formatted.

# %% [markdown]
# ## Import Libraries
#
# Let's begin with importing the required libraries.

# %%
import pandas as pd
import os

# %% [markdown]
# ## Diving In
#
# There's no better way to start than loading the CSV files into dataframes to see how they're formatted.

# %%
df_arrivals = pd.read_csv('./data/raw-data/arrivals/API_ST.INT.ARVL_DS2_en_csv_v2_5994899.csv')

df_arrivals.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                               Indicator Name Indicator Code  1960  1961  1962  \
# 0  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 1  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 2  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 3  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
# 4  International tourism, number of arrivals    ST.INT.ARVL   NaN   NaN   NaN
#
#    1963  1964  1965  ...          2014          2015          2016  \
# 0   NaN   NaN   NaN  ...  1.739000e+06  1.832000e+06  1.758000e+06
# 1   NaN   NaN   NaN  ...  3.573839e+07  3.531868e+07  3.764589e+07
# ...

# %%
df_metadata_country = pd.read_csv('./data/raw-data/arrivals/Metadata_Country_API_ST.INT.ARVL_DS2_en_csv_v2_5994899.csv')

df_metadata_country.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFE                        NaN                  NaN
# 2          AFG                 South Asia           Low income
# 3          AFW                        NaN                  NaN
# 4          AGO         Sub-Saharan Africa  Lower middle income
#
#                                         SpecialNotes  \
# 0                                                NaN
# 1  26 countries, stretching from the Red Sea in t...
# 2  The reporting period for national accounts dat...
# 3  22 countries, stretching from the westernmost ...
# 4  The World Bank systematically assesses the app...
#
#                      TableName  Unnamed: 5
# 0                        Aruba         NaN
# 1  Africa Eastern and Southern         NaN
# 2                  Afghanistan         NaN
# 3   Africa Western and Central         NaN
# 4                       Angola         NaN

# %%
df_departures = pd.read_csv('./data/raw-data/departures/API_ST.INT.DPRT_DS2_en_csv_v2_5996775.csv')

df_departures.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                 Indicator Name Indicator Code  1960  1961  \
# 0  International tourism, number of departures    ST.INT.DPRT   NaN   NaN
# 1  International tourism, number of departures    ST.INT.DPRT   NaN   NaN
# 2  International tourism, number of departures    ST.INT.DPRT   NaN   NaN
# 3  International tourism, number of departures    ST.INT.DPRT   NaN   NaN
# 4  International tourism, number of departures    ST.INT.DPRT   NaN   NaN
#
#    1962  1963  1964  1965  ...  2014  2015  2016  2017  2018  2019  2020  \
# 0   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...

# %%
df_expenditures = pd.read_csv('./data/raw-data/expenditures/API_ST.INT.XPND.CD_DS2_en_csv_v2_5996767.csv')

df_expenditures.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name  Indicator Code  1960  \
# 0  International tourism, expenditures (current US$)  ST.INT.XPND.CD   NaN
# 1  International tourism, expenditures (current US$)  ST.INT.XPND.CD   NaN
# 2  International tourism, expenditures (current US$)  ST.INT.XPND.CD   NaN
# 3  International tourism, expenditures (current US$)  ST.INT.XPND.CD   NaN
# 4  International tourism, expenditures (current US$)  ST.INT.XPND.CD   NaN
#
#    1961  1962  1963  1964  1965  ...          2014          2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  3.500000e+08  3.570000e+08
# 1   NaN   NaN   NaN   NaN   NaN  ...  1.373011e+10  1.352935e+10
# ...

# %%
df_receipts = pd.read_csv('./data/raw-data/receipts/API_ST.INT.RCPT.CD_DS2_en_csv_v2_5996774.csv')

df_receipts.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                   Indicator Name  Indicator Code  1960  1961  \
# 0  International tourism, receipts (current US$)  ST.INT.RCPT.CD   NaN   NaN
# 1  International tourism, receipts (current US$)  ST.INT.RCPT.CD   NaN   NaN
# 2  International tourism, receipts (current US$)  ST.INT.RCPT.CD   NaN   NaN
# 3  International tourism, receipts (current US$)  ST.INT.RCPT.CD   NaN   NaN
# 4  International tourism, receipts (current US$)  ST.INT.RCPT.CD   NaN   NaN
#
#    1962  1963  1964  1965  ...          2014          2015          2016  \
# 0   NaN   NaN   NaN   NaN  ...  1.625000e+09  1.659000e+09  1.757000e+09
# 1   NaN   NaN   NaN   NaN  ...  2.722080e+10  2.511940e+10  2.430525e+10
# ...

# %%
df_gdp = pd.read_csv('./data/raw-data/gdp/API_NY.GDP.MKTP.KD_DS2_en_csv_v2_5994841.csv')

df_gdp.head()
# Out:
#                   Country Name Country Code           Indicator Name  \
# 0                        Aruba          ABW  GDP (constant 2015 US$)
# 1  Africa Eastern and Southern          AFE  GDP (constant 2015 US$)
# 2                  Afghanistan          AFG  GDP (constant 2015 US$)
# 3   Africa Western and Central          AFW  GDP (constant 2015 US$)
# 4                       Angola          AGO  GDP (constant 2015 US$)
#
#    Indicator Code          1960          1961          1962          1963  \
# 0  NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# 1  NY.GDP.MKTP.KD  1.540941e+11  1.544869e+11  1.667931e+11  1.753799e+11
# 2  NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
# 3  NY.GDP.MKTP.KD  1.058619e+11  1.078255e+11  1.118935e+11  1.200378e+11
# 4  NY.GDP.MKTP.KD           NaN           NaN           NaN           NaN
#
#            1964          1965  ...          2014          2015          2016  \
# ...

# %%
df_gdp_per_capita = pd.read_csv('./data/raw-data/gdp-per-capita/API_NY.GDP.PCAP.KD_DS2_en_csv_v2_5994684.csv')

df_gdp_per_capita.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                        Indicator Name  Indicator Code         1960  \
# 0  GDP per capita (constant 2015 US$)  NY.GDP.PCAP.KD          NaN
# 1  GDP per capita (constant 2015 US$)  NY.GDP.PCAP.KD  1179.058077
# 2  GDP per capita (constant 2015 US$)  NY.GDP.PCAP.KD          NaN
# 3  GDP per capita (constant 2015 US$)  NY.GDP.PCAP.KD  1088.483404
# 4  GDP per capita (constant 2015 US$)  NY.GDP.PCAP.KD          NaN
#
#           1961         1962         1963         1964         1965  ...  \
# 0          NaN          NaN          NaN          NaN          NaN  ...
# 1  1151.433058  1210.086966  1238.291625  1259.640033  1290.327575  ...
# 2          NaN          NaN          NaN          NaN          NaN  ...
# ...

# %%
df_income = pd.read_csv('./data/raw-data/income/API_NY.ADJ.NNTY.PC.CD_DS2_en_csv_v2_5996043.csv')

df_income.head()
# Out:
#                   Country Name Country Code  \
# 0                        Aruba          ABW
# 1  Africa Eastern and Southern          AFE
# 2                  Afghanistan          AFG
# 3   Africa Western and Central          AFW
# 4                       Angola          AGO
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
# 1  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
# 2  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
# 3  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
# 4  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD   NaN
#
#    1961  1962  1963  1964  1965  ...          2014          2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  23163.637761  24192.616602
# 1   NaN   NaN   NaN   NaN   NaN  ...   1310.864153   1228.102810
# ...

# %% [markdown]
# Based on this, it's clear that there is a realtively clear and consistant format for most of the datasets. The only one that is noticeably different is the country metadata CSV. With all of this info in mind, we can move onto the next step: cleaning the data and using it to create a SQL database.
